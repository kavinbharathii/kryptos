# %%
# data collected from own code, in main.py
data = [('k', 8.24742268041237), ('s', 6.185567010309279), ('t', 6.185567010309279), ('u', 6.185567010309279), ('b', 5.154639175257731), ('o', 5.154639175257731), ('w', 5.154639175257731), ('a', 4.123711340206185), ('f', 4.123711340206185), ('g', 4.123711340206185), ('i', 4.123711340206185), ('l', 4.123711340206185), ('q', 4.123711340206185), ('r', 4.123711340206185), ('z', 4.123711340206185), ('d', 3.0927835051546393), ('j', 3.0927835051546393), ('n', 3.0927835051546393), ('p', 3.0927835051546393), ('c', 2.0618556701030926), ('e', 2.0618556701030926), ('h', 2.0618556701030926), ('v', 2.0618556701030926), ('x', 2.0618556701030926), ('m', 1.0309278350515463), ('y', 1.0309278350515463)]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [i[0] for i in data]
y = [i[1] for i in data]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 26 artists>

# %%
# data collected from https://en.wikipedia.org/wiki/Letter_frequency
englishAlphabetFrequencyData = [('E', 12.02), ('T', 9.10), ('A', 8.12), ('O', 7.68), ('I', 7.31), ('N', 6.95), ('S', 6.28), ('R', 6.02), ('H', 5.92), ('D', 4.32), ('L', 3.98), ('U', 2.88), ('C', 2.71), ('M', 2.61), ('F', 2.30), ('Y', 2.11), ('W', 2.09), ('G', 2.03), ('P', 1.82), ('B', 1.49), ('V', 1.11), ('K', 0.69), ('X', 0.17), ('Q', 0.11), ('J', 0.10), ('Z', 0.07)]

# %%
x1 = [i[0] for i in englishAlphabetFrequencyData]
y1 = [i[1] for i in englishAlphabetFrequencyData]

# %%
plt.bar(x1, y1, color='r')
# Out:
# <BarContainer object of 26 artists>
